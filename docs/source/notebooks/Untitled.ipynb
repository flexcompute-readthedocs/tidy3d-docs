# %%
import numpy as np

inf = np.inf

# %%
sim_dict_momchil = {'boundary_spec': {'type': 'BoundarySpec',
                   'x': {'minus': {'bloch_vec': 0.0,
                                   'name': None,
                                   'type': 'BlochBoundary'},
                         'plus': {'bloch_vec': 0.0,
                                  'name': None,
                                  'type': 'BlochBoundary'},
                         'type': 'Boundary'},
                   'y': {'minus': {'name': None, 'type': 'Periodic'},
                         'plus': {'name': None, 'type': 'Periodic'},
                         'type': 'Boundary'},
                   'z': {'minus': {'name': None,
                                   'num_layers': 40,
                                   'parameters': {'alpha_max': 0.0,
                                                  'alpha_min': 0.0,
                                                  'alpha_order': 1,
                                                  'kappa_max': 3.0,
                                                  'kappa_min': 1.0,
                                                  'kappa_order': 3,
                                                  'sigma_max': 1.5,
                                                  'sigma_min': 0.0,
                                                  'sigma_order': 3,
                                                  'type': 'PMLParams'},
                                   'type': 'PML'},
                         'plus': {'name': None,
                                  'num_layers': 40,
                                  'parameters': {'alpha_max': 0.0,
                                                 'alpha_min': 0.0,
                                                 'alpha_order': 1,
                                                 'kappa_max': 3.0,
                                                 'kappa_min': 1.0,
                                                 'kappa_order': 3,
                                                 'sigma_max': 1.5,
                                                 'sigma_min': 0.0,
                                                 'sigma_order': 3,
                                                 'type': 'PMLParams'},
                                  'type': 'PML'},
                         'type': 'Boundary'}},
 'center': (0.0, 0.0, 0.0),
 'courant': 0.99,
 'grid_spec': {'grid_x': {'dl': 0.01, 'type': 'UniformGrid'},
               'grid_y': {'dl': 0.01, 'type': 'UniformGrid'},
               'grid_z': {'dl': 0.01, 'type': 'UniformGrid'},
               'override_structures': (),
               'type': 'GridSpec',
               'wavelength': None},
 'medium': {'conductivity': 0.0,
            'frequency_range': None,
            'name': None,
            'permittivity': 1.9599999999999997,
            'type': 'Medium'},
 'monitors': ({'apodization': {'end': None,
                               'start': None,
                               'type': 'ApodizationSpec',
                               'width': None},
               'center': (0.0, 0.0, 0.0),
               'colocate': False,
               'fields': ('Ex', 'Ey', 'Ez', 'Hx', 'Hy', 'Hz'),
               'freqs': (180000000000000.0,),
               'interval_space': (1, 1, 1),
               'name': 'field_grad',
               'size': (inf, inf, 1.5),
               'type': 'FieldMonitor'},
              {'apodization': {'end': None,
                               'start': None,
                               'type': 'ApodizationSpec',
                               'width': None},
               'center': (0.0, 0.0, 0.0),
               'freqs': (180000000000000.0,),
               'name': 'eps_grad',
               'size': (inf, inf, 1.5),
               'type': 'PermittivityMonitor'}),
 'normalize_index': 0,
 'run_time': 2.5e-12,
 'shutoff': 1e-08,
 'size': (0.5, 0.0, 5.5),
 'sources': ({'angle_phi': 0.0,
              'angle_theta': 0.0,
              'center': (0.0, 0.0, 1.25103770934502),
              'direction': '-',
              'name': None,
              'pol_angle': 0.0,
              'size': (inf, inf, 0.0),
              'source_time': {'amplitude': 1.0,
                              'freq0': 200000000000000.0,
                              'fwidth': 20000000000000.0,
                              'offset': 5.0,
                              'phase': 0.0,
                              'type': 'GaussianPulse'},
              'type': 'PlaneWave'},),
 'structures': ({'geometry': {'center': (0.0, 0.0, -0.5),
                              'size': (inf, inf, 0.5),
                              'type': 'Box'},
                 'medium': {'conductivity': 0.0,
                            'frequency_range': None,
                            'name': None,
                            'permittivity': 4.0,
                            'type': 'Medium'},
                 'name': None,
                 'type': 'Structure'},
                {'geometry': {'center': (0.0, 0.0, -0.125),
                              'size': (inf, inf, 0.25),
                              'type': 'Box'},
                 'medium': {'conductivity': 0.0,
                            'frequency_range': None,
                            'name': None,
                            'permittivity': 3.24,
                            'type': 'Medium'},
                 'name': None,
                 'type': 'Structure'},
                {'geometry': {'center': (0.0, 0.0, 0.25),
                              'size': (inf, inf, 0.5),
                              'type': 'Box'},
                 'medium': {'conductivity': 0.0,
                            'frequency_range': None,
                            'name': None,
                            'permittivity': 2.25,
                            'type': 'Medium'},
                 'name': None,
                 'type': 'Structure'},
                {'geometry': {'center': (0.0, 0.0, 0.625),
                              'size': (inf, inf, 0.25),
                              'type': 'Box'},
                 'medium': {'conductivity': 0.0,
                            'frequency_range': None,
                            'name': None,
                            'permittivity': 3.61,
                            'type': 'Medium'},
                 'name': None,
                 'type': 'Structure'}),
 'subpixel': True,
 'symmetry': (0, 0, 0),
 'type': 'Simulation',
 'version': '1.8.0'}

# %%
sim_dict_plugin = {'boundary_spec': {'type': 'BoundarySpec',
                   'x': {'minus': {'bloch_vec': 0.0,
                                   'name': None,
                                   'type': 'BlochBoundary'},
                         'plus': {'bloch_vec': 0.0,
                                  'name': None,
                                  'type': 'BlochBoundary'},
                         'type': 'Boundary'},
                   'y': {'minus': {'name': None, 'type': 'Periodic'},
                         'plus': {'name': None, 'type': 'Periodic'},
                         'type': 'Boundary'},
                   'z': {'minus': {'name': None,
                                   'num_layers': 40,
                                   'parameters': {'alpha_max': 0.0,
                                                  'alpha_min': 0.0,
                                                  'alpha_order': 1,
                                                  'kappa_max': 3.0,
                                                  'kappa_min': 1.0,
                                                  'kappa_order': 3,
                                                  'sigma_max': 1.5,
                                                  'sigma_min': 0.0,
                                                  'sigma_order': 3,
                                                  'type': 'PMLParams'},
                                   'type': 'PML'},
                         'plus': {'name': None,
                                  'num_layers': 40,
                                  'parameters': {'alpha_max': 0.0,
                                                 'alpha_min': 0.0,
                                                 'alpha_order': 1,
                                                 'kappa_max': 3.0,
                                                 'kappa_min': 1.0,
                                                 'kappa_order': 3,
                                                 'sigma_max': 1.5,
                                                 'sigma_min': 0.0,
                                                 'sigma_order': 3,
                                                 'type': 'PMLParams'},
                                  'type': 'PML'},
                         'type': 'Boundary'}},
 'center': (0.0, 0.0, 0.0),
 'courant': 0.99,
 'grad_eps_monitors': ({'apodization': {'end': None,
                                        'start': None,
                                        'type': 'ApodizationSpec',
                                        'width': None},
                        'center': (0.0, 0.0, -0.5),
                        'freqs': (200000000000000.0,),
                        'name': 'grad_mnt_0_eps',
                        'size': (inf, inf, 0.5000002384185791),
                        'type': 'PermittivityMonitor'},
                       {'apodization': {'end': None,
                                        'start': None,
                                        'type': 'ApodizationSpec',
                                        'width': None},
                        'center': (0.0, 0.0, -0.125),
                        'freqs': (200000000000000.0,),
                        'name': 'grad_mnt_1_eps',
                        'size': (inf, inf, 0.2500002384185791),
                        'type': 'PermittivityMonitor'},
                       {'apodization': {'end': None,
                                        'start': None,
                                        'type': 'ApodizationSpec',
                                        'width': None},
                        'center': (0.0, 0.0, 0.25),
                        'freqs': (200000000000000.0,),
                        'name': 'grad_mnt_2_eps',
                        'size': (inf, inf, 0.5000002384185791),
                        'type': 'PermittivityMonitor'},
                       {'apodization': {'end': None,
                                        'start': None,
                                        'type': 'ApodizationSpec',
                                        'width': None},
                        'center': (0.0, 0.0, 0.625),
                        'freqs': (200000000000000.0,),
                        'name': 'grad_mnt_3_eps',
                        'size': (inf, inf, 0.2500002384185791),
                        'type': 'PermittivityMonitor'}),
 'grad_monitors': ({'apodization': {'end': None,
                                    'start': None,
                                    'type': 'ApodizationSpec',
                                    'width': None},
                    'center': (0.0, 0.0, -0.5),
                    'colocate': False,
                    'fields': ('Ex', 'Ey', 'Ez'),
                    'freqs': (200000000000000.0,),
                    'interval_space': (1, 1, 1),
                    'name': 'grad_mnt_0_field',
                    'size': (inf, inf, 0.5000002384185791),
                    'type': 'FieldMonitor'},
                   {'apodization': {'end': None,
                                    'start': None,
                                    'type': 'ApodizationSpec',
                                    'width': None},
                    'center': (0.0, 0.0, -0.125),
                    'colocate': False,
                    'fields': ('Ex', 'Ey', 'Ez'),
                    'freqs': (200000000000000.0,),
                    'interval_space': (1, 1, 1),
                    'name': 'grad_mnt_1_field',
                    'size': (inf, inf, 0.2500002384185791),
                    'type': 'FieldMonitor'},
                   {'apodization': {'end': None,
                                    'start': None,
                                    'type': 'ApodizationSpec',
                                    'width': None},
                    'center': (0.0, 0.0, 0.25),
                    'colocate': False,
                    'fields': ('Ex', 'Ey', 'Ez'),
                    'freqs': (200000000000000.0,),
                    'interval_space': (1, 1, 1),
                    'name': 'grad_mnt_2_field',
                    'size': (inf, inf, 0.5000002384185791),
                    'type': 'FieldMonitor'},
                   {'apodization': {'end': None,
                                    'start': None,
                                    'type': 'ApodizationSpec',
                                    'width': None},
                    'center': (0.0, 0.0, 0.625),
                    'colocate': False,
                    'fields': ('Ex', 'Ey', 'Ez'),
                    'freqs': (200000000000000.0,),
                    'interval_space': (1, 1, 1),
                    'name': 'grad_mnt_3_field',
                    'size': (inf, inf, 0.2500002384185791),
                    'type': 'FieldMonitor'}),
 'grid_spec': {'grid_x': {'dl': 0.0125, 'type': 'UniformGrid'},
               'grid_y': {'dl': 0.0125, 'type': 'UniformGrid'},
               'grid_z': {'dl': 0.0125, 'type': 'UniformGrid'},
               'override_structures': (),
               'type': 'GridSpec',
               'wavelength': None},
 'input_structures': ({'geometry': {'center': (0, 0, 0.5),
                                    'size': (inf, inf, 0.5),
                                    'type': 'JaxBox'},
                       'medium': {'conductivity': 0.0,
                                  'frequency_range': None,
                                  'name': None,
                                  'permittivity': 4.0,
                                  'type': 'JaxMedium'},
                       'name': None,
                       'type': 'JaxStructure'},
                      {'geometry': {'center': (0, 0, 0.125),
                                    'size': (inf, inf, 0.25),
                                    'type': 'JaxBox'},
                       'medium': {'conductivity': 0.0,
                                  'frequency_range': None,
                                  'name': None,
                                  'permittivity': 3.24,
                                  'type': 'JaxMedium'},
                       'name': None,
                       'type': 'JaxStructure'},
                      {'geometry': {'center': (0, 0, 0.25),
                                    'size': (inf, inf, 0.5),
                                    'type': 'JaxBox'},
                       'medium': {'conductivity': 0.0,
                                  'frequency_range': None,
                                  'name': None,
                                  'permittivity': 2.25,
                                  'type': 'JaxMedium'},
                       'name': None,
                       'type': 'JaxStructure'},
                      {'geometry': {'center': (0, 0, 0.625),
                                    'size': (inf, inf, 0.25),
                                    'type': 'JaxBox'},
                       'medium': {'conductivity': 0.0,
                                  'frequency_range': None,
                                  'name': None,
                                  'permittivity': 3.61,
                                  'type': 'JaxMedium'},
                       'name': None,
                       'type': 'JaxStructure'}),
 'medium': {'conductivity': 0.0,
            'frequency_range': None,
            'name': None,
            'permittivity': 1.9599999999999997,
            'type': 'Medium'},
 'monitors': (),
 'normalize_index': 0,
 'output_monitors': (),
 'run_time': 2.5e-12,
 'shutoff': 1e-08,
 'size': (0.2, 0.2, 5.5),
 'sources': ({'angle_phi': 0.0,
              'angle_theta': 0.0,
              'center': (0.0, 0.0, 1.25103770934502),
              'direction': '-',
              'name': None,
              'pol_angle': 0.0,
              'size': (inf, inf, 0.0),
              'source_time': {'amplitude': 0.003477510847290415,
                              'freq0': 200000000000000.0,
                              'fwidth': 40000000000000.0,
                              'offset': 5.0,
                              'phase': 0.1994802889455907,
                              'type': 'GaussianPulse'},
              'type': 'PlaneWave'},),
 'structures': (),
 'subpixel': True,
 'symmetry': (0, 0, 0),
 'type': 'JaxSimulation',
 'version': '1.8.0'}

# %%
a = sim_dict_momchil
b = sim_dict_plugin

# %%
for k in a.keys():
    if a[k] != b[k]:
        print(k)
# Out:
# grid_spec
# monitors
# size
# sources
# structures
# type

# %%
a['sources']
# Out:
# ({'angle_phi': 0.0,
#   'angle_theta': 0.0,
#   'center': (0.0, 0.0, 1.25103770934502),
#   'direction': '-',
#   'name': None,
#   'pol_angle': 0.0,
#   'size': (inf, inf, 0.0),
#   'source_time': {'amplitude': 1.0,
#    'freq0': 200000000000000.0,
#    'fwidth': 20000000000000.0,
#    'offset': 5.0,
#    'phase': 0.0,
#    'type': 'GaussianPulse'},
#   'type': 'PlaneWave'},)

# %%
b['sources']
# Out:
# ({'angle_phi': 0.0,
#   'angle_theta': 0.0,
#   'center': (0.0, 0.0, 1.25103770934502),
#   'direction': '-',
#   'name': None,
#   'pol_angle': 0.0,
#   'size': (inf, inf, 0.0),
#   'source_time': {'amplitude': 0.003477510847290415,
#    'freq0': 200000000000000.0,
#    'fwidth': 40000000000000.0,
#    'offset': 5.0,
#    'phase': 0.1994802889455907,
#    'type': 'GaussianPulse'},
#   'type': 'PlaneWave'},)

# %%
amp_a = 1.0
phase_a = 0.0

phase_b = 0.1994802889455907
amp_b = 0.003477510847290415

# %%
b_complex = amp_b * np.exp(1j * phase_b)
print(b_complex)

# b_complex / abs(b_complex)
# Out:
# (0.003408550750464201+0.0006891033845022321j)

# %%
amps = 0.93398277-0.29135976j
np.conj(amps)
# Out:
# (0.93398277+0.29135976j)

# %%
a_complex / abs(a_complex)
# Out:
# (-0.2978001938931167+0.9546282231933133j)

# %%
z = (b_complex / np.conj(amps))

# %%
z
# Out:
# (0.003535576706329205-0.00036512600346517705j)
