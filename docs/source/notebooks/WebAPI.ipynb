# %% [markdown]
# # Running simulations through the cloud
#
# This notebook is a tutorial of the API used for submitting simulations to our servers.

# %%
import tidy3d as td
import tidy3d.web as web

# set logging level to ERROR because we'll only running simulations to demonstrate the web API, we dont care about the results.
td.config.logging_level = "ERROR"

# %% [markdown]
# ## Setup
#
# Let's set up a simple simulation to get started.

# %%
# whether to print output in web functions, note: if False (default) they will all run silently
verbose = True

# set up parameters of simulation
dl = 0.05
pml = td.PML()
sim_size = [4, 4, 4]
freq0 = 3e14
fwidth = 1e13
run_time = 1 / fwidth

# create structure
dielectric = td.Medium.from_nk(n=2, k=0, freq=freq0)
square = td.Structure(
    geometry=td.Box(center=[0, 0, 0], size=[1.5, 1.5, 1.5]), medium=dielectric
)

# create source
source = td.UniformCurrentSource(
    center=(-1.5, 0, 0),
    size=(0, 0.4, 0.4),
    source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
    polarization="Ex",
)

# create monitor
monitor = td.FieldMonitor(
    fields=["Ex", "Ey", "Ez"],
    center=(0, 0, 0),
    size=(td.inf, td.inf, 0),
    freqs=[freq0],
    name="field",
)

# Initialize simulation
sim = td.Simulation(
    size=sim_size,
    grid_spec=td.GridSpec.uniform(dl),
    structures=[square],
    sources=[source],
    monitors=[monitor],
    run_time=run_time,
    boundary_spec=td.BoundarySpec.all_sides(boundary=pml),
)

# %% [markdown]
# ## Running simulation manually
#
# For the most control, you can run the simulation through the Tidy3D web API.
# Each simulation running on the server is identified by a `task_id`, which must be specified in the web API.
# Let's walk through submitting a simulation this way.

# %%
# upload the simulation to our servers
task_id = web.upload(sim, task_name="webAPI", verbose=verbose)

# start the simulation running
web.start(task_id)

# monitor the simulation, dont move on to next line until completed.
web.monitor(task_id, verbose=verbose)

# download the results and load into a simulation data object for plotting, post processing etc.
sim_data = web.load(task_id, path="data/sim.hdf5", verbose=verbose)
# Out:
# 00:17:17 PST Created task 'webAPI' with task_id
#              'fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=535644;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=783896;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\taskId]8;;\]8;id=535644;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\=]8;;\]8;id=744502;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\fdve]8;;\]8;id=535644;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\-15d1b10b-20f]8;;\
#              ]8;id=535644;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\d-4154-81a3-ed315eabd1d1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:17:18 PST status = queued
# Output()
# 00:17:23 PST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 00:17:28 PST Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to get
#              the billed FlexCredit cost after a simulation run.
#              starting up solver
#              running solver
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:17:35 PST status = postprocess
# Output()
# 00:17:39 PST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              View simulation result at
#              ]8;id=536582;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=135303;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\taskId]8;;\]8;id=536582;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\=]8;;\]8;id=226788;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\fdve]8;;\]8;id=536582;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\-15d1b10b-20f]8;;\
#              ]8;id=536582;https://tidy3d.simulation.cloud/workbench?taskId=fdve-15d1b10b-20fd-4154-81a3-ed315eabd1d1\d-4154-81a3-ed315eabd1d1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              loading simulation from data/sim.hdf5

# %% [markdown]
# While we broke down each of the individual steps above, one can also perform the entire process in one line by calling the [web.run()](../_autosummary/tidy3d.web.run.html) function as follows.
#
# ```python
# sim_data = web.run(sim, task_name='webAPI', path='data/sim.hdf5')
# ```
#
# (We won't run it again in this notebook to save time).
#
# Sometimes this is more convenient, but other times it can be helpful to have the steps broken down one by one, for example if the simulation is long, you may want to [web.start](../_autosummary/tidy3d.web.start.html) and then exit the session and load the results at a later time using [web.load](../_autosummary/tidy3d.web.load.html).

# %% [markdown]
# ## Job Container
#
# The [web.Job](../_autosummary/tidy3d.web.Job.html) interface provides a more convenient way to manage single simuations, mainly because it eliminates the need for keeping track of the `task_id` and original [Simulation](../_autosummary/tidy3d.Simulation.html).
#
# We can get the cost estimate of running the task before actually running it. This prevents us from accidentally running large jobs that we set up by mistake. The estimated cost is the maximum cost corresponding to running all the time steps.

# %%
# initializes job, puts task on server (but doesnt run it)
job = web.Job(simulation=sim, task_name="job", verbose=verbose)

# estimate the maximum cost
estimated_cost = web.estimate_cost(job.task_id)
# Out:
# 00:17:40 PST Created task 'job' with task_id
#              'fdve-a8896bd9-894f-47af-92ae-3ca249df8542' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=467850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=122830;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\taskId]8;;\]8;id=467850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\=]8;;\]8;id=177839;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\fdve]8;;\]8;id=467850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\-a8896bd9-894]8;;\
#              ]8;id=467850;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\f-47af-92ae-3ca249df8542']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:17:41 PST Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.

# %% [markdown]
# While [Job](../_autosummary/tidy3d.web.Job.html) has methods with names identical to the web API functions above, which give some more granular control, it is often most convenient to call `.run()` so we will do that now.

# %%
# start job, monitor, and load results
sim_data = job.run(path="data/sim.hdf5")
# Out:
#              status = queued
# Output()
# 00:17:46 PST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 00:17:51 PST Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to get
#              the billed FlexCredit cost after a simulation run.
#              starting up solver
#              running solver
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# 00:17:58 PST status = postprocess
# 00:18:02 PST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              View simulation result at
#              ]8;id=393514;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=893640;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\taskId]8;;\]8;id=393514;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\=]8;;\]8;id=458039;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\fdve]8;;\]8;id=393514;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\-a8896bd9-894]8;;\
#              ]8;id=393514;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8896bd9-894f-47af-92ae-3ca249df8542\f-47af-92ae-3ca249df8542']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:03 PST loading simulation from data/sim.hdf5

# %% [markdown]
# Another convenient thing about [Job](../_autosummary/tidy3d.web.Job.html) objects is that they can be saved and loaded just like other Tidy3d components.
#
# This is convenient if you want to save and load up the results of a job that has already finished, without needing to know the `task_id`.

# %%
# saves the job metadata to a single file
job.to_file("data/job.json")

# can exit session, break here, or continue in new session.

# load the job metadata from file
job_loaded = web.Job.from_file("data/job.json")

# download the data from the server and load it into a SimulationData object.
sim_data = job_loaded.load(path="data/sim.hdf5")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:04 PST loading simulation from data/sim.hdf5

# %% [markdown]
# ## Batch Processing
#
# Commonly one needs to submit a batch of Simulations.
# One way to approach this using the web API is to upload, start, monitor, and load a series of tasks one by one, but this is clumsy and you can lose your data if the session gets interrupted.
#
# A better way is to use the built-in [Batch](../_autosummary/tidy3d.web.Batch.html) object.
# The batch object is like a [Job](../_autosummary/tidy3d.web.Job.html), but stores task metadata for a series of simulations.

# %%
# make a dictionary of  {task name : simulation} for demonstration
sims = {f"sim_{i}": sim for i in range(3)}

# initialize a batch and run them all
batch = web.Batch(simulations=sims, verbose=verbose)

# run the batch and store all of the data in the `data/` dir.
batch_results = batch.run(path_dir="data")
# Out:
#              Created task 'sim_0' with task_id
#              'fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=99198;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=400935;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc\taskId]8;;\]8;id=99198;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc\=]8;;\]8;id=2462;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc\fdve]8;;\]8;id=99198;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc\-d45eb05d-ff2]8;;\
#              ]8;id=99198;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc\b-47a9-ba69-4599720082bc']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Created task 'sim_1' with task_id
#              'fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=465815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=144381;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf\taskId]8;;\]8;id=465815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf\=]8;;\]8;id=609861;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf\fdve]8;;\]8;id=465815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf\-b2524d07-e5a]8;;\
#              ]8;id=465815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf\f-411d-9676-75eeb3b62bdf']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:05 PST Created task 'sim_2' with task_id
#              'fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=944329;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=265276;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f\taskId]8;;\]8;id=944329;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f\=]8;;\]8;id=879074;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f\fdve]8;;\]8;id=944329;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f\-4e4c4775-8f1]8;;\
#              ]8;id=944329;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f\2-4153-b0f1-cbc89d65068f']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:06 PST Started working on Batch.
# 00:18:07 PST Maximum FlexCredit cost: 0.075 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after the
#              Batch has completed.
# Output()
# 00:18:28 PST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# When the batch is completed, the output is not a [SimulationData](../_autosummary/tidy3d.SimulationData.html) but rather a [BatchData](../_autosummary/tidy3d.web.BatchData.html).  The data within this [BatchData](../_autosummary/tidy3d.web.BatchData.html) object can either be indexed directly `batch_results[task_name]` or can be looped through `batch_results.items()` to get the [SimulationData](../_autosummary/tidy3d.SimulationData.html) for each task.
#
# This was chosen to reduce the memory strain from loading all [SimulationData](../_autosummary/tidy3d.SimulationData.html) objects at once.
#
# Alternatively, the batch can be looped through (several times) using the `.items()` method, similar to a dictionary.

# %%
# grab the sum of intensities in the simulation one by one (to save memory)
intensities = {}
for task_name, sim_data in batch_results.items():
    intensity = sim_data.get_intensity("field").sel(f=freq0)
    sum_intensity = float(intensity.sum(("x", "y")).values)
    intensities[task_name] = sum_intensity

print(intensities)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:29 PST loading simulation from
#              data/fdve-d45eb05d-ff2b-47a9-ba69-4599720082bc.hdf5
# /tmp/ipykernel_207610/711851585.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   sum_intensity = float(intensity.sum(("x", "y")).values)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              loading simulation from
#              data/fdve-b2524d07-e5af-411d-9676-75eeb3b62bdf.hdf5
# /tmp/ipykernel_207610/711851585.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   sum_intensity = float(intensity.sum(("x", "y")).values)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:30 PST loading simulation from
#              data/fdve-4e4c4775-8f12-4153-b0f1-cbc89d65068f.hdf5
# {'sim_0': 6377911.0, 'sim_1': 6377911.0, 'sim_2': 6377911.0}
# /tmp/ipykernel_207610/711851585.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   sum_intensity = float(intensity.sum(("x", "y")).values)

# %% [markdown]
# ## Asynchronous Batching
#
# Finally, one can make use of the [asyncio package](https://realpython.com/async-io-python/) to perform asynchronous processing of several simulations.
#
# For this purpose, a [web.run_async](../_autosummary/tidy3d.web.run_async.html) function is provided, which works like the regular `web.run` but accepts a dictionary of simulations.
#
# Here is the previous example repeated using this feature.

# %%
batch_results = web.run_async(simulations=sims, verbose=verbose)
# Out:
#              Created task 'sim_0' with task_id
#              'fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=464973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=597739;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd\taskId]8;;\]8;id=464973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd\=]8;;\]8;id=12661;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd\fdve]8;;\]8;id=464973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd\-4868b4b7-854]8;;\
#              ]8;id=464973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd\d-4811-9cdf-8f25b1545dbd']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:31 PST Created task 'sim_1' with task_id
#              'fdve-5f2cc35f-5f91-4382-b938-a667efc9f711' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=271071;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5f2cc35f-5f91-4382-b938-a667efc9f711\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=617573;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5f2cc35f-5f91-4382-b938-a667efc9f711\taskId]8;;\]8;id=271071;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5f2cc35f-5f91-4382-b938-a667efc9f711\=]8;;\]8;id=632762;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5f2cc35f-5f91-4382-b938-a667efc9f711\fdve]8;;\]8;id=271071;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5f2cc35f-5f91-4382-b938-a667efc9f711\-5f2cc35f-5f9]8;;\
#              ]8;id=271071;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5f2cc35f-5f91-4382-b938-a667efc9f711\1-4382-b938-a667efc9f711']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Created task 'sim_2' with task_id
#              'fdve-e21a89c0-71e2-470c-8368-4539f7c4358f' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=578035;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e21a89c0-71e2-470c-8368-4539f7c4358f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=480371;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e21a89c0-71e2-470c-8368-4539f7c4358f\taskId]8;;\]8;id=578035;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e21a89c0-71e2-470c-8368-4539f7c4358f\=]8;;\]8;id=162413;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e21a89c0-71e2-470c-8368-4539f7c4358f\fdve]8;;\]8;id=578035;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e21a89c0-71e2-470c-8368-4539f7c4358f\-e21a89c0-71e]8;;\
#              ]8;id=578035;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e21a89c0-71e2-470c-8368-4539f7c4358f\2-470c-8368-4539f7c4358f']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:33 PST Started working on Batch.
#              Maximum FlexCredit cost: 0.075 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after the
#              Batch has completed.
# Output()
# 00:18:53 PST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
# grab the sum of intensities in the simulation one by one (to save memory)
intensities = {}
for task_name, sim_data in batch_results.items():
    intensity = sim_data.get_intensity("field").sel(f=freq0)
    sum_intensity = float(intensity.sum(("x", "y")).values)
    intensities[task_name] = sum_intensity

print(intensities)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:54 PST loading simulation from
#              ./fdve-4868b4b7-854d-4811-9cdf-8f25b1545dbd.hdf5
# /tmp/ipykernel_207610/711851585.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   sum_intensity = float(intensity.sum(("x", "y")).values)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 00:18:55 PST loading simulation from
#              ./fdve-5f2cc35f-5f91-4382-b938-a667efc9f711.hdf5
# /tmp/ipykernel_207610/711851585.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   sum_intensity = float(intensity.sum(("x", "y")).values)
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              loading simulation from
#              ./fdve-e21a89c0-71e2-470c-8368-4539f7c4358f.hdf5
# {'sim_0': 6377911.0, 'sim_1': 6377911.0, 'sim_2': 6377911.0}
# /tmp/ipykernel_207610/711851585.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   sum_intensity = float(intensity.sum(("x", "y")).values)

# %% [markdown]
# After going through this tutorial, you have learned how to run simulations with Tidy3D via the web API. If you are new to Tidy3D or the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials and [example library](https://www.flexcompute.com/tidy3d/examples/) before starting your own simulation adventure.
